# %% [markdown]
# # EE559 Homework 3,4 - Ishaan Vasant (6989506537)

# %% [markdown]
# ## 1. Time Series Classification
#
# ### a) Download the AReM data from: https://archive.ics.uci.edu/ml/datasets/ Activity+Recognition+system+based+on+Multisensor+data+fusion+\%28AReM\ %29 . The dataset contains 7 folders that represent seven types of activities. In each folder, there are multiple files each of which represents an instant of a human performing an activity. Each file containis 6 time series collected from activities of the same person. There are 88 instances in the dataset, each of which contains 6 time series and each time series has 480 consecutive values.

# %%
import pandas as pd

# %%
import numpy as np

# %%
cd /Users/ishaan/Desktop/AReM/bending1
# Out:
# /Users/ishaan/Desktop/AReM/bending1

# %%
pwd
# Out:
# '/Users/ishaan/Desktop/AReM/bending1'

# %%
bend1d1= pd.read_csv("dataset1.csv",skiprows=4)
bend1d2= pd.read_csv("dataset2.csv",skiprows=4)
bend1d3= pd.read_csv("dataset3.csv",skiprows=4)
bend1d4= pd.read_csv("dataset4.csv",skiprows=4)
bend1d5= pd.read_csv("dataset5.csv",skiprows=4)
bend1d6= pd.read_csv("dataset6.csv",skiprows=4)
bend1d7= pd.read_csv("dataset7.csv",skiprows=4)

# %%
cd /Users/ishaan/Desktop/AReM/bending2
# Out:
# /Users/ishaan/Desktop/AReM/bending2

# %%
bend2d1= pd.read_csv("dataset1.csv",skiprows=4)
bend2d2= pd.read_csv("dataset2.csv",skiprows=4)
bend2d3= pd.read_csv("dataset3.csv",skiprows=4)
bend2d4= pd.read_csv("dataset4.csv",skiprows=4)
bend2d5= pd.read_csv("dataset5.csv",skiprows=4)
bend2d6= pd.read_csv("dataset6.csv",skiprows=4)

# %%
cd /Users/ishaan/Desktop/AReM/cycling
# Out:
# /Users/ishaan/Desktop/AReM/cycling

# %%
cycd1=pd.read_csv("dataset1.csv",skiprows=4)
cycd2=pd.read_csv("dataset2.csv",skiprows=4)
cycd3=pd.read_csv("dataset3.csv",skiprows=4)
cycd4=pd.read_csv("dataset4.csv",skiprows=4)
cycd5=pd.read_csv("dataset5.csv",skiprows=4)
cycd6=pd.read_csv("dataset6.csv",skiprows=4)
cycd7=pd.read_csv("dataset7.csv",skiprows=4)
cycd8=pd.read_csv("dataset8.csv",skiprows=4)
cycd9=pd.read_csv("dataset9.csv",skiprows=4)
cycd10=pd.read_csv("dataset10.csv",skiprows=4)
cycd11=pd.read_csv("dataset11.csv",skiprows=4)
cycd12=pd.read_csv("dataset12.csv",skiprows=4)
cycd13=pd.read_csv("dataset13.csv",skiprows=4)
cycd14=pd.read_csv("dataset14.csv",skiprows=4)
cycd15=pd.read_csv("dataset15.csv",skiprows=4)

# %%
cd /Users/ishaan/Desktop/AReM/lying
# Out:
# /Users/ishaan/Desktop/AReM/lying

# %%
lyingd1=pd.read_csv("dataset1.csv",skiprows=4)
lyingd2=pd.read_csv("dataset2.csv",skiprows=4)
lyingd3=pd.read_csv("dataset3.csv",skiprows=4)
lyingd4=pd.read_csv("dataset4.csv",skiprows=4)
lyingd5=pd.read_csv("dataset5.csv",skiprows=4)
lyingd6=pd.read_csv("dataset6.csv",skiprows=4)
lyingd7=pd.read_csv("dataset7.csv",skiprows=4)
lyingd8=pd.read_csv("dataset8.csv",skiprows=4)
lyingd9=pd.read_csv("dataset9.csv",skiprows=4)
lyingd10=pd.read_csv("dataset10.csv",skiprows=4)
lyingd11=pd.read_csv("dataset11.csv",skiprows=4)
lyingd12=pd.read_csv("dataset12.csv",skiprows=4)
lyingd13=pd.read_csv("dataset13.csv",skiprows=4)
lyingd14=pd.read_csv("dataset14.csv",skiprows=4)
lyingd15=pd.read_csv("dataset15.csv",skiprows=4)

# %%
cd /Users/ishaan/Desktop/AReM/sitting
# Out:
# /Users/ishaan/Desktop/AReM/sitting

# %%
sitd1=pd.read_csv("dataset1.csv",skiprows=4)
sitd2=pd.read_csv("dataset2.csv",skiprows=4)
sitd3=pd.read_csv("dataset3.csv",skiprows=4)
sitd4=pd.read_csv("dataset4.csv",skiprows=4)
sitd5=pd.read_csv("dataset5.csv",skiprows=4)
sitd6=pd.read_csv("dataset6.csv",skiprows=4)
sitd7=pd.read_csv("dataset7.csv",skiprows=4)
sitd8=pd.read_csv("dataset8.csv",skiprows=4)
sitd9=pd.read_csv("dataset9.csv",skiprows=4)
sitd10=pd.read_csv("dataset10.csv",skiprows=4)
sitd11=pd.read_csv("dataset11.csv",skiprows=4)
sitd12=pd.read_csv("dataset12.csv",skiprows=4)
sitd13=pd.read_csv("dataset13.csv",skiprows=4)
sitd14=pd.read_csv("dataset14.csv",skiprows=4)
sitd15=pd.read_csv("dataset15.csv",skiprows=4)

# %%
cd /Users/ishaan/Desktop/AReM/standing
# Out:
# /Users/ishaan/Desktop/AReM/standing

# %%
stand1=pd.read_csv("dataset1.csv",skiprows=4)
stand2=pd.read_csv("dataset2.csv",skiprows=4)
stand3=pd.read_csv("dataset3.csv",skiprows=4)
stand4=pd.read_csv("dataset4.csv",skiprows=4)
stand5=pd.read_csv("dataset5.csv",skiprows=4)
stand6=pd.read_csv("dataset6.csv",skiprows=4)
stand7=pd.read_csv("dataset7.csv",skiprows=4)
stand8=pd.read_csv("dataset8.csv",skiprows=4)
stand9=pd.read_csv("dataset9.csv",skiprows=4)
stand10=pd.read_csv("dataset10.csv",skiprows=4)
stand11=pd.read_csv("dataset11.csv",skiprows=4)
stand12=pd.read_csv("dataset12.csv",skiprows=4)
stand13=pd.read_csv("dataset13.csv",skiprows=4)
stand14=pd.read_csv("dataset14.csv",skiprows=4)
stand15=pd.read_csv("dataset15.csv",skiprows=4)

# %%
cd /Users/ishaan/Desktop/AReM/walking
# Out:
# /Users/ishaan/Desktop/AReM/walking

# %%
walkd1=pd.read_csv("dataset1.csv",skiprows=4)
walkd2=pd.read_csv("dataset2.csv",skiprows=4)
walkd3=pd.read_csv("dataset3.csv",skiprows=4)
walkd4=pd.read_csv("dataset4.csv",skiprows=4)
walkd5=pd.read_csv("dataset5.csv",skiprows=4)
walkd6=pd.read_csv("dataset6.csv",skiprows=4)
walkd7=pd.read_csv("dataset7.csv",skiprows=4)
walkd8=pd.read_csv("dataset8.csv",skiprows=4)
walkd9=pd.read_csv("dataset9.csv",skiprows=4)
walkd10=pd.read_csv("dataset10.csv",skiprows=4)
walkd11=pd.read_csv("dataset11.csv",skiprows=4)
walkd12=pd.read_csv("dataset12.csv",skiprows=4)
walkd13=pd.read_csv("dataset13.csv",skiprows=4)
walkd14=pd.read_csv("dataset14.csv",skiprows=4)
walkd15=pd.read_csv("dataset15.csv",skiprows=4)

# %%
cd /Users/ishaan/Desktop/
# Out:
# /Users/ishaan/Desktop

# %%
bend1=[0, bend1d1, bend1d2, bend1d3, bend1d4, bend1d5, bend1d6, bend1d7]
bend2=[0, bend2d1, bend2d2, bend2d3, bend2d4, bend2d5, bend2d6]
cyc=[0, cycd1, cycd2, cycd3, cycd4, cycd5, cycd6, cycd7, cycd8, cycd9, cycd10, cycd11, cycd12, cycd13, cycd14, cycd15]
lying=[0, lyingd1, lyingd2, lyingd3, lyingd4, lyingd5, lyingd6, lyingd7, lyingd8, lyingd9, lyingd10, lyingd11, lyingd12, lyingd13, lyingd14, lyingd15]
sit=[0, sitd1, sitd2, sitd3, sitd4, sitd5, sitd6, sitd7, sitd8, sitd9, sitd10, sitd11, sitd12, sitd13, sitd14, sitd15]
stand=[0, stand1, stand2, stand3, stand4, stand5, stand6, stand7, stand8, stand9, stand10, stand11, stand12, stand13, stand14, stand15]
walk=[0, walkd1, walkd2, walkd3, walkd4, walkd5, walkd6, walkd7, walkd8, walkd9, walkd10, walkd11, walkd12, walkd13, walkd14, walkd15]

# %% [markdown]
# ### b) Keep datasets 1 and 2 in folders bending1 and bending 2, as well as datasets 1, 2, and 3 in other folders as test data and other datasets as train data.

# %%
frames=[bend1d1, bend1d2, bend2d1, bend2d2, cycd1, cycd2, cycd3, lyingd1, lyingd2, lyingd3, sitd1, sitd2, sitd3, stand1, stand2, stand3, walkd1, walkd2, walkd3]
frames1=[bend1d3, bend1d4, bend1d5, bend1d6, bend1d7, bend2d3, bend2d4, bend2d5, bend2d6, cycd4, cycd5, cycd6, cycd7, cycd8, cycd9, cycd10, cycd11, cycd12, cycd13, cycd14, cycd15, lyingd4, lyingd5, lyingd6, lyingd7, lyingd8, lyingd9, lyingd10, lyingd11, lyingd12, lyingd13, lyingd14, lyingd15, sitd4, sitd5, sitd6, sitd7, sitd8, sitd9, sitd10, sitd11, sitd12, sitd13, sitd14, sitd15, stand4, stand5, stand6, stand7, stand8, stand9, stand10, stand11, stand12, stand13, stand14, stand15, walkd4, walkd5, walkd6, walkd7, walkd8, walkd9, walkd10, walkd11, walkd12, walkd13, walkd14, walkd15]
test=pd.concat(frames)
train=pd.concat(frames1)

# %% [markdown]
# ### c) i) Research what types of time-domain features are usually used in time series classification and list them (examples are minimum, maximum, mean, etc).

# %% [markdown]
# #### Types of features
#
# #### Means in each of the d dimensions
# #### Standard deviations of the d dimensions
# #### Skewness, Kurtosis and Higher order moments of the d dimensions
# #### Maximum, Median and Minimum values
# #### First quartile and third quartile

# %% [markdown]
# ### c) ii)

# %%
min1b1=[]
min2b1=[]
min3b1=[]
min4b1=[]
min5b1=[]
min6b1=[]
for i in range(1,8):
    a=np.min(bend1[i].avg_rss12)
    min1b1.append(a)
    b=np.min(bend1[i].var_rss12)
    min2b1.append(b)
    c=np.min(bend1[i].avg_rss13)
    min3b1.append(c)
    d=np.min(bend1[i].var_rss13)
    min4b1.append(d)
    e=np.min(bend1[i].avg_rss23)
    min5b1.append(e)
    f=np.min(bend1[i].var_rss23)
    min6b1.append(f)

min1b2=[]
min2b2=[]
min3b2=[]
min4b2=[]
min5b2=[]
min6b2=[]
for i in range(1,7):
    a=np.min(bend2[i].avg_rss12)
    min1b2.append(a)
    b=np.min(bend2[i].var_rss12)
    min2b2.append(b)
    c=np.min(bend2[i].avg_rss13)
    min3b2.append(c)
    d=np.min(bend2[i].var_rss13)
    min4b2.append(d)
    e=np.min(bend2[i].avg_rss23)
    min5b2.append(e)
    f=np.min(bend2[i].var_rss23)
    min6b2.append(f)
    
min1cyc=[]
min2cyc=[]
min3cyc=[]
min4cyc=[]
min5cyc=[]
min6cyc=[]
for i in range(1,16):
    a=np.min(cyc[i].avg_rss12)
    min1cyc.append(a)
    b=np.min(cyc[i].var_rss12)
    min2cyc.append(b)
    c=np.min(cyc[i].avg_rss13)
    min3cyc.append(c)
    d=np.min(cyc[i].var_rss13)
    min4cyc.append(d)
    e=np.min(cyc[i].avg_rss23)
    min5cyc.append(e)
    f=np.min(cyc[i].var_rss23)
    min6cyc.append(f)
    
min1lying=[]
min2lying=[]
min3lying=[]
min4lying=[]
min5lying=[]
min6lying=[]
for i in range(1,16):
    a=np.min(lying[i].avg_rss12)
    min1lying.append(a)
    b=np.min(lying[i].var_rss12)
    min2lying.append(b)
    c=np.min(lying[i].avg_rss13)
    min3lying.append(c)
    d=np.min(lying[i].var_rss13)
    min4lying.append(d)
    e=np.min(lying[i].avg_rss23)
    min5lying.append(e)
    f=np.min(lying[i].var_rss23)
    min6lying.append(f)
    
min1sit=[]
min2sit=[]
min3sit=[]
min4sit=[]
min5sit=[]
min6sit=[]
for i in range(1,16):
    a=np.min(sit[i].avg_rss12)
    min1sit.append(a)
    b=np.min(sit[i].var_rss12)
    min2sit.append(b)
    c=np.min(sit[i].avg_rss13)
    min3sit.append(c)
    d=np.min(sit[i].var_rss13)
    min4sit.append(d)
    e=np.min(sit[i].avg_rss23)
    min5sit.append(e)
    f=np.min(sit[i].var_rss23)
    min6sit.append(f)
    
min1stand=[]
min2stand=[]
min3stand=[]
min4stand=[]
min5stand=[]
min6stand=[]
for i in range(1,16):
    a=np.min(stand[i].avg_rss12)
    min1stand.append(a)
    b=np.min(stand[i].var_rss12)
    min2stand.append(b)
    c=np.min(stand[i].avg_rss13)
    min3stand.append(c)
    d=np.min(stand[i].var_rss13)
    min4stand.append(d)
    e=np.min(stand[i].avg_rss23)
    min5stand.append(e)
    f=np.min(stand[i].var_rss23)
    min6stand.append(f)
    
min1walk=[]
min2walk=[]
min3walk=[]
min4walk=[]
min5walk=[]
min6walk=[]
for i in range(1,16):
    a=np.min(walk[i].avg_rss12)
    min1walk.append(a)
    b=np.min(walk[i].var_rss12)
    min2walk.append(b)
    c=np.min(walk[i].avg_rss13)
    min3walk.append(c)
    d=np.min(walk[i].var_rss13)
    min4walk.append(d)
    e=np.min(walk[i].avg_rss23)
    min5walk.append(e)
    f=np.min(walk[i].var_rss23)
    min6walk.append(f)
    
min1=min1b1 + min1b2 + min1cyc + min1lying + min1sit + min1stand + min1walk
min2=min2b1 + min2b2 + min2cyc + min2lying + min2sit + min2stand + min2walk
min3=min3b1 + min3b2 + min3cyc + min3lying + min3sit + min3stand + min3walk
min4=min4b1 + min4b2 + min4cyc + min4lying + min4sit + min4stand + min4walk
min5=min5b1 + min5b2 + min5cyc + min5lying + min5sit + min5stand + min5walk
min6=min6b1 + min6b2 + min6cyc + min6lying + min6sit + min6stand + min6walk

# %%
max1b1=[]
max2b1=[]
max3b1=[]
max4b1=[]
max5b1=[]
max6b1=[]
for i in range(1,8):
    a=np.max(bend1[i].avg_rss12)
    max1b1.append(a)
    b=np.max(bend1[i].var_rss12)
    max2b1.append(b)
    c=np.max(bend1[i].avg_rss13)
    max3b1.append(c)
    d=np.max(bend1[i].var_rss13)
    max4b1.append(d)
    e=np.max(bend1[i].avg_rss23)
    max5b1.append(e)
    f=np.max(bend1[i].var_rss23)
    max6b1.append(f)

max1b2=[]
max2b2=[]
max3b2=[]
max4b2=[]
max5b2=[]
max6b2=[]
for i in range(1,7):
    a=np.max(bend2[i].avg_rss12)
    max1b2.append(a)
    b=np.max(bend2[i].var_rss12)
    max2b2.append(b)
    c=np.max(bend2[i].avg_rss13)
    max3b2.append(c)
    d=np.max(bend2[i].var_rss13)
    max4b2.append(d)
    e=np.max(bend2[i].avg_rss23)
    max5b2.append(e)
    f=np.max(bend2[i].var_rss23)
    max6b2.append(f)
    
max1cyc=[]
max2cyc=[]
max3cyc=[]
max4cyc=[]
max5cyc=[]
max6cyc=[]
for i in range(1,16):
    a=np.max(cyc[i].avg_rss12)
    max1cyc.append(a)
    b=np.max(cyc[i].var_rss12)
    max2cyc.append(b)
    c=np.max(cyc[i].avg_rss13)
    max3cyc.append(c)
    d=np.max(cyc[i].var_rss13)
    max4cyc.append(d)
    e=np.max(cyc[i].avg_rss23)
    max5cyc.append(e)
    f=np.max(cyc[i].var_rss23)
    max6cyc.append(f)
    
max1lying=[]
max2lying=[]
max3lying=[]
max4lying=[]
max5lying=[]
max6lying=[]
for i in range(1,16):
    a=np.max(lying[i].avg_rss12)
    max1lying.append(a)
    b=np.max(lying[i].var_rss12)
    max2lying.append(b)
    c=np.max(lying[i].avg_rss13)
    max3lying.append(c)
    d=np.max(lying[i].var_rss13)
    max4lying.append(d)
    e=np.max(lying[i].avg_rss23)
    max5lying.append(e)
    f=np.max(lying[i].var_rss23)
    max6lying.append(f)
    
max1sit=[]
max2sit=[]
max3sit=[]
max4sit=[]
max5sit=[]
max6sit=[]
for i in range(1,16):
    a=np.max(sit[i].avg_rss12)
    max1sit.append(a)
    b=np.max(sit[i].var_rss12)
    max2sit.append(b)
    c=np.max(sit[i].avg_rss13)
    max3sit.append(c)
    d=np.max(sit[i].var_rss13)
    max4sit.append(d)
    e=np.max(sit[i].avg_rss23)
    max5sit.append(e)
    f=np.max(sit[i].var_rss23)
    max6sit.append(f)
    
max1stand=[]
max2stand=[]
max3stand=[]
max4stand=[]
max5stand=[]
max6stand=[]
for i in range(1,16):
    a=np.max(stand[i].avg_rss12)
    max1stand.append(a)
    b=np.max(stand[i].var_rss12)
    max2stand.append(b)
    c=np.max(stand[i].avg_rss13)
    max3stand.append(c)
    d=np.max(stand[i].var_rss13)
    max4stand.append(d)
    e=np.max(stand[i].avg_rss23)
    max5stand.append(e)
    f=np.max(stand[i].var_rss23)
    max6stand.append(f)
    
max1walk=[]
max2walk=[]
max3walk=[]
max4walk=[]
max5walk=[]
max6walk=[]
for i in range(1,16):
    a=np.max(walk[i].avg_rss12)
    max1walk.append(a)
    b=np.max(walk[i].var_rss12)
    max2walk.append(b)
    c=np.max(walk[i].avg_rss13)
    max3walk.append(c)
    d=np.max(walk[i].var_rss13)
    max4walk.append(d)
    e=np.max(walk[i].avg_rss23)
    max5walk.append(e)
    f=np.max(walk[i].var_rss23)
    max6walk.append(f)
    
max1=max1b1 + max1b2 + max1cyc + max1lying + max1sit + max1stand + max1walk
max2=max2b1 + max2b2 + max2cyc + max2lying + max2sit + max2stand + max2walk
max3=max3b1 + max3b2 + max3cyc + max3lying + max3sit + max3stand + max3walk
max4=max4b1 + max4b2 + max4cyc + max4lying + max4sit + max4stand + max4walk
max5=max5b1 + max5b2 + max5cyc + max5lying + max5sit + max5stand + max5walk
max6=max6b1 + max6b2 + max6cyc + max6lying + max6sit + max6stand + max6walk

# %%
mean1b1=[]
mean2b1=[]
mean3b1=[]
mean4b1=[]
mean5b1=[]
mean6b1=[]
for i in range(1,8):
    a=np.mean(bend1[i].avg_rss12)
    mean1b1.append(a)
    b=np.mean(bend1[i].var_rss12)
    mean2b1.append(b)
    c=np.mean(bend1[i].avg_rss13)
    mean3b1.append(c)
    d=np.mean(bend1[i].var_rss13)
    mean4b1.append(d)
    e=np.mean(bend1[i].avg_rss23)
    mean5b1.append(e)
    f=np.mean(bend1[i].var_rss23)
    mean6b1.append(f)

mean1b2=[]
mean2b2=[]
mean3b2=[]
mean4b2=[]
mean5b2=[]
mean6b2=[]
for i in range(1,7):
    a=np.mean(bend2[i].avg_rss12)
    mean1b2.append(a)
    b=np.mean(bend2[i].var_rss12)
    mean2b2.append(b)
    c=np.mean(bend2[i].avg_rss13)
    mean3b2.append(c)
    d=np.mean(bend2[i].var_rss13)
    mean4b2.append(d)
    e=np.mean(bend2[i].avg_rss23)
    mean5b2.append(e)
    f=np.mean(bend2[i].var_rss23)
    mean6b2.append(f)
    
mean1cyc=[]
mean2cyc=[]
mean3cyc=[]
mean4cyc=[]
mean5cyc=[]
mean6cyc=[]
for i in range(1,16):
    a=np.mean(cyc[i].avg_rss12)
    mean1cyc.append(a)
    b=np.mean(cyc[i].var_rss12)
    mean2cyc.append(b)
    c=np.mean(cyc[i].avg_rss13)
    mean3cyc.append(c)
    d=np.mean(cyc[i].var_rss13)
    mean4cyc.append(d)
    e=np.mean(cyc[i].avg_rss23)
    mean5cyc.append(e)
    f=np.mean(cyc[i].var_rss23)
    mean6cyc.append(f)
    
mean1lying=[]
mean2lying=[]
mean3lying=[]
mean4lying=[]
mean5lying=[]
mean6lying=[]
for i in range(1,16):
    a=np.mean(lying[i].avg_rss12)
    mean1lying.append(a)
    b=np.mean(lying[i].var_rss12)
    mean2lying.append(b)
    c=np.mean(lying[i].avg_rss13)
    mean3lying.append(c)
    d=np.mean(lying[i].var_rss13)
    mean4lying.append(d)
    e=np.mean(lying[i].avg_rss23)
    mean5lying.append(e)
    f=np.mean(lying[i].var_rss23)
    mean6lying.append(f)
    
mean1sit=[]
mean2sit=[]
mean3sit=[]
mean4sit=[]
mean5sit=[]
mean6sit=[]
for i in range(1,16):
    a=np.mean(sit[i].avg_rss12)
    mean1sit.append(a)
    b=np.mean(sit[i].var_rss12)
    mean2sit.append(b)
    c=np.mean(sit[i].avg_rss13)
    mean3sit.append(c)
    d=np.mean(sit[i].var_rss13)
    mean4sit.append(d)
    e=np.mean(sit[i].avg_rss23)
    mean5sit.append(e)
    f=np.mean(sit[i].var_rss23)
    mean6sit.append(f)
    
mean1stand=[]
mean2stand=[]
mean3stand=[]
mean4stand=[]
mean5stand=[]
mean6stand=[]
for i in range(1,16):
    a=np.mean(stand[i].avg_rss12)
    mean1stand.append(a)
    b=np.mean(stand[i].var_rss12)
    mean2stand.append(b)
    c=np.mean(stand[i].avg_rss13)
    mean3stand.append(c)
    d=np.mean(stand[i].var_rss13)
    mean4stand.append(d)
    e=np.mean(stand[i].avg_rss23)
    mean5stand.append(e)
    f=np.mean(stand[i].var_rss23)
    mean6stand.append(f)
    
mean1walk=[]
mean2walk=[]
mean3walk=[]
mean4walk=[]
mean5walk=[]
mean6walk=[]
for i in range(1,16):
    a=np.mean(walk[i].avg_rss12)
    mean1walk.append(a)
    b=np.mean(walk[i].var_rss12)
    mean2walk.append(b)
    c=np.mean(walk[i].avg_rss13)
    mean3walk.append(c)
    d=np.mean(walk[i].var_rss13)
    mean4walk.append(d)
    e=np.mean(walk[i].avg_rss23)
    mean5walk.append(e)
    f=np.mean(walk[i].var_rss23)
    mean6walk.append(f)
    
mean1=mean1b1 + mean1b2 + mean1cyc + mean1lying + mean1sit + mean1stand + mean1walk
mean2=mean2b1 + mean2b2 + mean2cyc + mean2lying + mean2sit + mean2stand + mean2walk
mean3=mean3b1 + mean3b2 + mean3cyc + mean3lying + mean3sit + mean3stand + mean3walk
mean4=mean4b1 + mean4b2 + mean4cyc + mean4lying + mean4sit + mean4stand + mean4walk
mean5=mean5b1 + mean5b2 + mean5cyc + mean5lying + mean5sit + mean5stand + mean5walk
mean6=mean6b1 + mean6b2 + mean6cyc + mean6lying + mean6sit + mean6stand + mean6walk

# %%
median1b1=[]
median2b1=[]
median3b1=[]
median4b1=[]
median5b1=[]
median6b1=[]
for i in range(1,8):
    a=np.median(bend1[i].avg_rss12)
    median1b1.append(a)
    b=np.median(bend1[i].var_rss12)
    median2b1.append(b)
    c=np.median(bend1[i].avg_rss13)
    median3b1.append(c)
    d=np.median(bend1[i].var_rss13)
    median4b1.append(d)
    e=np.median(bend1[i].avg_rss23)
    median5b1.append(e)
    f=np.median(bend1[i].var_rss23)
    median6b1.append(f)

median1b2=[]
median2b2=[]
median3b2=[]
median4b2=[]
median5b2=[]
median6b2=[]
for i in range(1,7):
    a=np.median(bend2[i].avg_rss12)
    median1b2.append(a)
    b=np.median(bend2[i].var_rss12)
    median2b2.append(b)
    c=np.median(bend2[i].avg_rss13)
    median3b2.append(c)
    d=np.median(bend2[i].var_rss13)
    median4b2.append(d)
    e=np.median(bend2[i].avg_rss23)
    median5b2.append(e)
    f=np.median(bend2[i].var_rss23)
    median6b2.append(f)
    
median1cyc=[]
median2cyc=[]
median3cyc=[]
median4cyc=[]
median5cyc=[]
median6cyc=[]
for i in range(1,16):
    a=np.median(cyc[i].avg_rss12)
    median1cyc.append(a)
    b=np.median(cyc[i].var_rss12)
    median2cyc.append(b)
    c=np.median(cyc[i].avg_rss13)
    median3cyc.append(c)
    d=np.median(cyc[i].var_rss13)
    median4cyc.append(d)
    e=np.median(cyc[i].avg_rss23)
    median5cyc.append(e)
    f=np.median(cyc[i].var_rss23)
    median6cyc.append(f)
    
median1lying=[]
median2lying=[]
median3lying=[]
median4lying=[]
median5lying=[]
median6lying=[]
for i in range(1,16):
    a=np.median(lying[i].avg_rss12)
    median1lying.append(a)
    b=np.median(lying[i].var_rss12)
    median2lying.append(b)
    c=np.median(lying[i].avg_rss13)
    median3lying.append(c)
    d=np.median(lying[i].var_rss13)
    median4lying.append(d)
    e=np.median(lying[i].avg_rss23)
    median5lying.append(e)
    f=np.median(lying[i].var_rss23)
    median6lying.append(f)
    
median1sit=[]
median2sit=[]
median3sit=[]
median4sit=[]
median5sit=[]
median6sit=[]
for i in range(1,16):
    a=np.median(sit[i].avg_rss12)
    median1sit.append(a)
    b=np.median(sit[i].var_rss12)
    median2sit.append(b)
    c=np.median(sit[i].avg_rss13)
    median3sit.append(c)
    d=np.median(sit[i].var_rss13)
    median4sit.append(d)
    e=np.median(sit[i].avg_rss23)
    median5sit.append(e)
    f=np.median(sit[i].var_rss23)
    median6sit.append(f)
    
median1stand=[]
median2stand=[]
median3stand=[]
median4stand=[]
median5stand=[]
median6stand=[]
for i in range(1,16):
    a=np.median(stand[i].avg_rss12)
    median1stand.append(a)
    b=np.median(stand[i].var_rss12)
    median2stand.append(b)
    c=np.median(stand[i].avg_rss13)
    median3stand.append(c)
    d=np.median(stand[i].var_rss13)
    median4stand.append(d)
    e=np.median(stand[i].avg_rss23)
    median5stand.append(e)
    f=np.median(stand[i].var_rss23)
    median6stand.append(f)
    
median1walk=[]
median2walk=[]
median3walk=[]
median4walk=[]
median5walk=[]
median6walk=[]
for i in range(1,16):
    a=np.median(walk[i].avg_rss12)
    median1walk.append(a)
    b=np.median(walk[i].var_rss12)
    median2walk.append(b)
    c=np.median(walk[i].avg_rss13)
    median3walk.append(c)
    d=np.median(walk[i].var_rss13)
    median4walk.append(d)
    e=np.median(walk[i].avg_rss23)
    median5walk.append(e)
    f=np.median(walk[i].var_rss23)
    median6walk.append(f)
    
median1=median1b1 + median1b2 + median1cyc + median1lying + median1sit + median1stand + median1walk
median2=median2b1 + median2b2 + median2cyc + median2lying + median2sit + median2stand + median2walk
median3=median3b1 + median3b2 + median3cyc + median3lying + median3sit + median3stand + median3walk
median4=median4b1 + median4b2 + median4cyc + median4lying + median4sit + median4stand + median4walk
median5=median5b1 + median5b2 + median5cyc + median5lying + median5sit + median5stand + median5walk
median6=median6b1 + median6b2 + median6cyc + median6lying + median6sit + median6stand + median6walk

# %%
std1b1=[]
std2b1=[]
std3b1=[]
std4b1=[]
std5b1=[]
std6b1=[]
for i in range(1,8):
    a=np.std(bend1[i].avg_rss12)
    std1b1.append(a)
    b=np.std(bend1[i].var_rss12)
    std2b1.append(b)
    c=np.std(bend1[i].avg_rss13)
    std3b1.append(c)
    d=np.std(bend1[i].var_rss13)
    std4b1.append(d)
    e=np.std(bend1[i].avg_rss23)
    std5b1.append(e)
    f=np.std(bend1[i].var_rss23)
    std6b1.append(f)

std1b2=[]
std2b2=[]
std3b2=[]
std4b2=[]
std5b2=[]
std6b2=[]
for i in range(1,7):
    a=np.std(bend2[i].avg_rss12)
    std1b2.append(a)
    b=np.std(bend2[i].var_rss12)
    std2b2.append(b)
    c=np.std(bend2[i].avg_rss13)
    std3b2.append(c)
    d=np.std(bend2[i].var_rss13)
    std4b2.append(d)
    e=np.std(bend2[i].avg_rss23)
    std5b2.append(e)
    f=np.std(bend2[i].var_rss23)
    std6b2.append(f)
    
std1cyc=[]
std2cyc=[]
std3cyc=[]
std4cyc=[]
std5cyc=[]
std6cyc=[]
for i in range(1,16):
    a=np.std(cyc[i].avg_rss12)
    std1cyc.append(a)
    b=np.std(cyc[i].var_rss12)
    std2cyc.append(b)
    c=np.std(cyc[i].avg_rss13)
    std3cyc.append(c)
    d=np.std(cyc[i].var_rss13)
    std4cyc.append(d)
    e=np.std(cyc[i].avg_rss23)
    std5cyc.append(e)
    f=np.std(cyc[i].var_rss23)
    std6cyc.append(f)
    
std1lying=[]
std2lying=[]
std3lying=[]
std4lying=[]
std5lying=[]
std6lying=[]
for i in range(1,16):
    a=np.std(lying[i].avg_rss12)
    std1lying.append(a)
    b=np.std(lying[i].var_rss12)
    std2lying.append(b)
    c=np.std(lying[i].avg_rss13)
    std3lying.append(c)
    d=np.std(lying[i].var_rss13)
    std4lying.append(d)
    e=np.std(lying[i].avg_rss23)
    std5lying.append(e)
    f=np.std(lying[i].var_rss23)
    std6lying.append(f)
    
std1sit=[]
std2sit=[]
std3sit=[]
std4sit=[]
std5sit=[]
std6sit=[]
for i in range(1,16):
    a=np.std(sit[i].avg_rss12)
    std1sit.append(a)
    b=np.std(sit[i].var_rss12)
    std2sit.append(b)
    c=np.std(sit[i].avg_rss13)
    std3sit.append(c)
    d=np.std(sit[i].var_rss13)
    std4sit.append(d)
    e=np.std(sit[i].avg_rss23)
    std5sit.append(e)
    f=np.std(sit[i].var_rss23)
    std6sit.append(f)
    
std1stand=[]
std2stand=[]
std3stand=[]
std4stand=[]
std5stand=[]
std6stand=[]
for i in range(1,16):
    a=np.std(stand[i].avg_rss12)
    std1stand.append(a)
    b=np.std(stand[i].var_rss12)
    std2stand.append(b)
    c=np.std(stand[i].avg_rss13)
    std3stand.append(c)
    d=np.std(stand[i].var_rss13)
    std4stand.append(d)
    e=np.std(stand[i].avg_rss23)
    std5stand.append(e)
    f=np.std(stand[i].var_rss23)
    std6stand.append(f)
    
std1walk=[]
std2walk=[]
std3walk=[]
std4walk=[]
std5walk=[]
std6walk=[]
for i in range(1,16):
    a=np.std(walk[i].avg_rss12)
    std1walk.append(a)
    b=np.std(walk[i].var_rss12)
    std2walk.append(b)
    c=np.std(walk[i].avg_rss13)
    std3walk.append(c)
    d=np.std(walk[i].var_rss13)
    std4walk.append(d)
    e=np.std(walk[i].avg_rss23)
    std5walk.append(e)
    f=np.std(walk[i].var_rss23)
    std6walk.append(f)
    
std1=std1b1 + std1b2 + std1cyc + std1lying + std1sit + std1stand + std1walk
std2=std2b1 + std2b2 + std2cyc + std2lying + std2sit + std2stand + std2walk
std3=std3b1 + std3b2 + std3cyc + std3lying + std3sit + std3stand + std3walk
std4=std4b1 + std4b2 + std4cyc + std4lying + std4sit + std4stand + std4walk
std5=std5b1 + std5b2 + std5cyc + std5lying + std5sit + std5stand + std5walk
std6=std6b1 + std6b2 + std6cyc + std6lying + std6sit + std6stand + std6walk

# %%
fquart1b1=[]
fquart2b1=[]
fquart3b1=[]
fquart4b1=[]
fquart5b1=[]
fquart6b1=[]
for i in range(1,8):
    a=np.percentile(bend1[i].avg_rss12,25)
    fquart1b1.append(a)
    b=np.percentile(bend1[i].var_rss12,25)
    fquart2b1.append(b)
    c=np.percentile(bend1[i].avg_rss13,25)
    fquart3b1.append(c)
    d=np.percentile(bend1[i].var_rss13,25)
    fquart4b1.append(d)
    e=np.percentile(bend1[i].avg_rss23,25)
    fquart5b1.append(e)
    f=np.percentile(bend1[i].var_rss23,25)
    fquart6b1.append(f)

fquart1b2=[]
fquart2b2=[]
fquart3b2=[]
fquart4b2=[]
fquart5b2=[]
fquart6b2=[]
for i in range(1,7):
    a=np.percentile(bend2[i].avg_rss12,25)
    fquart1b2.append(a)
    b=np.percentile(bend2[i].var_rss12,25)
    fquart2b2.append(b)
    c=np.percentile(bend2[i].avg_rss13,25)
    fquart3b2.append(c)
    d=np.percentile(bend2[i].var_rss13,25)
    fquart4b2.append(d)
    e=np.percentile(bend2[i].avg_rss23,25)
    fquart5b2.append(e)
    f=np.percentile(bend2[i].var_rss23,25)
    fquart6b2.append(f)
    
fquart1cyc=[]
fquart2cyc=[]
fquart3cyc=[]
fquart4cyc=[]
fquart5cyc=[]
fquart6cyc=[]
for i in range(1,16):
    a=np.percentile(cyc[i].avg_rss12,25)
    fquart1cyc.append(a)
    b=np.percentile(cyc[i].var_rss12,25)
    fquart2cyc.append(b)
    c=np.percentile(cyc[i].avg_rss13,25)
    fquart3cyc.append(c)
    d=np.percentile(cyc[i].var_rss13,25)
    fquart4cyc.append(d)
    e=np.percentile(cyc[i].avg_rss23,25)
    fquart5cyc.append(e)
    f=np.percentile(cyc[i].var_rss23,25)
    fquart6cyc.append(f)
    
fquart1lying=[]
fquart2lying=[]
fquart3lying=[]
fquart4lying=[]
fquart5lying=[]
fquart6lying=[]
for i in range(1,16):
    a=np.percentile(lying[i].avg_rss12,25)
    fquart1lying.append(a)
    b=np.percentile(lying[i].var_rss12,25)
    fquart2lying.append(b)
    c=np.percentile(lying[i].avg_rss13,25)
    fquart3lying.append(c)
    d=np.percentile(lying[i].var_rss13,25)
    fquart4lying.append(d)
    e=np.percentile(lying[i].avg_rss23,25)
    fquart5lying.append(e)
    f=np.percentile(lying[i].var_rss23,25)
    fquart6lying.append(f)
    
fquart1sit=[]
fquart2sit=[]
fquart3sit=[]
fquart4sit=[]
fquart5sit=[]
fquart6sit=[]
for i in range(1,16):
    a=np.percentile(sit[i].avg_rss12,25)
    fquart1sit.append(a)
    b=np.percentile(sit[i].var_rss12,25)
    fquart2sit.append(b)
    c=np.percentile(sit[i].avg_rss13,25)
    fquart3sit.append(c)
    d=np.percentile(sit[i].var_rss13,25)
    fquart4sit.append(d)
    e=np.percentile(sit[i].avg_rss23,25)
    fquart5sit.append(e)
    f=np.percentile(sit[i].var_rss23,25)
    fquart6sit.append(f)
    
fquart1stand=[]
fquart2stand=[]
fquart3stand=[]
fquart4stand=[]
fquart5stand=[]
fquart6stand=[]
for i in range(1,16):
    a=np.percentile(stand[i].avg_rss12,25)
    fquart1stand.append(a)
    b=np.percentile(stand[i].var_rss12,25)
    fquart2stand.append(b)
    c=np.percentile(stand[i].avg_rss13,25)
    fquart3stand.append(c)
    d=np.percentile(stand[i].var_rss13,25)
    fquart4stand.append(d)
    e=np.percentile(stand[i].avg_rss23,25)
    fquart5stand.append(e)
    f=np.percentile(stand[i].var_rss23,25)
    fquart6stand.append(f)
    
fquart1walk=[]
fquart2walk=[]
fquart3walk=[]
fquart4walk=[]
fquart5walk=[]
fquart6walk=[]
for i in range(1,16):
    a=np.percentile(walk[i].avg_rss12,25)
    fquart1walk.append(a)
    b=np.percentile(walk[i].var_rss12,25)
    fquart2walk.append(b)
    c=np.percentile(walk[i].avg_rss13,25)
    fquart3walk.append(c)
    d=np.percentile(walk[i].var_rss13,25)
    fquart4walk.append(d)
    e=np.percentile(walk[i].avg_rss23,25)
    fquart5walk.append(e)
    f=np.percentile(walk[i].var_rss23,25)
    fquart6walk.append(f)
    
fquart1=fquart1b1 + fquart1b2 + fquart1cyc + fquart1lying + fquart1sit + fquart1stand + fquart1walk
fquart2=fquart2b1 + fquart2b2 + fquart2cyc + fquart2lying + fquart2sit + fquart2stand + fquart2walk
fquart3=fquart3b1 + fquart3b2 + fquart3cyc + fquart3lying + fquart3sit + fquart3stand + fquart3walk
fquart4=fquart4b1 + fquart4b2 + fquart4cyc + fquart4lying + fquart4sit + fquart4stand + fquart4walk
fquart5=fquart5b1 + fquart5b2 + fquart5cyc + fquart5lying + fquart5sit + fquart5stand + fquart5walk
fquart6=fquart6b1 + fquart6b2 + fquart6cyc + fquart6lying + fquart6sit + fquart6stand + fquart6walk

# %%
tquart1b1=[]
tquart2b1=[]
tquart3b1=[]
tquart4b1=[]
tquart5b1=[]
tquart6b1=[]
for i in range(1,8):
    a=np.percentile(bend1[i].avg_rss12,75)
    tquart1b1.append(a)
    b=np.percentile(bend1[i].var_rss12,75)
    tquart2b1.append(b)
    c=np.percentile(bend1[i].avg_rss13,75)
    tquart3b1.append(c)
    d=np.percentile(bend1[i].var_rss13,75)
    tquart4b1.append(d)
    e=np.percentile(bend1[i].avg_rss23,75)
    tquart5b1.append(e)
    f=np.percentile(bend1[i].var_rss23,75)
    tquart6b1.append(f)

tquart1b2=[]
tquart2b2=[]
tquart3b2=[]
tquart4b2=[]
tquart5b2=[]
tquart6b2=[]
for i in range(1,7):
    a=np.percentile(bend2[i].avg_rss12,75)
    tquart1b2.append(a)
    b=np.percentile(bend2[i].var_rss12,75)
    tquart2b2.append(b)
    c=np.percentile(bend2[i].avg_rss13,75)
    tquart3b2.append(c)
    d=np.percentile(bend2[i].var_rss13,75)
    tquart4b2.append(d)
    e=np.percentile(bend2[i].avg_rss23,75)
    tquart5b2.append(e)
    f=np.percentile(bend2[i].var_rss23,75)
    tquart6b2.append(f)
    
tquart1cyc=[]
tquart2cyc=[]
tquart3cyc=[]
tquart4cyc=[]
tquart5cyc=[]
tquart6cyc=[]
for i in range(1,16):
    a=np.percentile(cyc[i].avg_rss12,75)
    tquart1cyc.append(a)
    b=np.percentile(cyc[i].var_rss12,75)
    tquart2cyc.append(b)
    c=np.percentile(cyc[i].avg_rss13,75)
    tquart3cyc.append(c)
    d=np.percentile(cyc[i].var_rss13,75)
    tquart4cyc.append(d)
    e=np.percentile(cyc[i].avg_rss23,75)
    tquart5cyc.append(e)
    f=np.percentile(cyc[i].var_rss23,75)
    tquart6cyc.append(f)
    
tquart1lying=[]
tquart2lying=[]
tquart3lying=[]
tquart4lying=[]
tquart5lying=[]
tquart6lying=[]
for i in range(1,16):
    a=np.percentile(lying[i].avg_rss12,75)
    tquart1lying.append(a)
    b=np.percentile(lying[i].var_rss12,75)
    tquart2lying.append(b)
    c=np.percentile(lying[i].avg_rss13,75)
    tquart3lying.append(c)
    d=np.percentile(lying[i].var_rss13,75)
    tquart4lying.append(d)
    e=np.percentile(lying[i].avg_rss23,75)
    tquart5lying.append(e)
    f=np.percentile(lying[i].var_rss23,75)
    tquart6lying.append(f)
    
tquart1sit=[]
tquart2sit=[]
tquart3sit=[]
tquart4sit=[]
tquart5sit=[]
tquart6sit=[]
for i in range(1,16):
    a=np.percentile(sit[i].avg_rss12,75)
    tquart1sit.append(a)
    b=np.percentile(sit[i].var_rss12,75)
    tquart2sit.append(b)
    c=np.percentile(sit[i].avg_rss13,75)
    tquart3sit.append(c)
    d=np.percentile(sit[i].var_rss13,75)
    tquart4sit.append(d)
    e=np.percentile(sit[i].avg_rss23,75)
    tquart5sit.append(e)
    f=np.percentile(sit[i].var_rss23,75)
    tquart6sit.append(f)
    
tquart1stand=[]
tquart2stand=[]
tquart3stand=[]
tquart4stand=[]
tquart5stand=[]
tquart6stand=[]
for i in range(1,16):
    a=np.percentile(stand[i].avg_rss12,75)
    tquart1stand.append(a)
    b=np.percentile(stand[i].var_rss12,75)
    tquart2stand.append(b)
    c=np.percentile(stand[i].avg_rss13,75)
    tquart3stand.append(c)
    d=np.percentile(stand[i].var_rss13,75)
    tquart4stand.append(d)
    e=np.percentile(stand[i].avg_rss23,75)
    tquart5stand.append(e)
    f=np.percentile(stand[i].var_rss23,75)
    tquart6stand.append(f)
    
tquart1walk=[]
tquart2walk=[]
tquart3walk=[]
tquart4walk=[]
tquart5walk=[]
tquart6walk=[]
for i in range(1,16):
    a=np.percentile(walk[i].avg_rss12,75)
    tquart1walk.append(a)
    b=np.percentile(walk[i].var_rss12,75)
    tquart2walk.append(b)
    c=np.percentile(walk[i].avg_rss13,75)
    tquart3walk.append(c)
    d=np.percentile(walk[i].var_rss13,75)
    tquart4walk.append(d)
    e=np.percentile(walk[i].avg_rss23,75)
    tquart5walk.append(e)
    f=np.percentile(walk[i].var_rss23,75)
    tquart6walk.append(f)
    
tquart1=tquart1b1 + tquart1b2 + tquart1cyc + tquart1lying + tquart1sit + tquart1stand + tquart1walk
tquart2=tquart2b1 + tquart2b2 + tquart2cyc + tquart2lying + tquart2sit + tquart2stand + tquart2walk
tquart3=tquart3b1 + tquart3b2 + tquart3cyc + tquart3lying + tquart3sit + tquart3stand + tquart3walk
tquart4=tquart4b1 + tquart4b2 + tquart4cyc + tquart4lying + tquart4sit + tquart4stand + tquart4walk
tquart5=tquart5b1 + tquart5b2 + tquart5cyc + tquart5lying + tquart5sit + tquart5stand + tquart5walk
tquart6=tquart6b1 + tquart6b2 + tquart6cyc + tquart6lying + tquart6sit + tquart6stand + tquart6walk

# %%
instance=[]
for i in range(1,89):
    instance.append(i)

# %%
from astropy.table import Table
t = Table([instance, min1, min2, min3, min4, min5, min6, max1, max2, max3, max4, max5, max6, mean1, mean2, mean3, mean4, mean5, mean6, median1, median2, median3, median4, median5, median6, std1, std2, std3, std4, std5, std6, fquart1, fquart2, fquart3, fquart4, fquart5, fquart6, tquart1, tquart2, tquart3, tquart4, tquart5, tquart6], names=('Instance', 'min1', 'min2', 'min3', 'min4', 'min5', 'min6', 'max1', 'max2', 'max3', 'max4', 'max5', 'max6', 'mean1', 'mean2', 'mean3', 'mean4', 'mean5', 'mean6', 'median1', 'median2', 'median3', 'median4', 'median5', 'median6', 'std1', 'std2', 'std3', 'std4', 'std5', 'std6', 'fquart1', 'fquart2', 'fquart3', 'fquart4', 'fquart5', 'fquart6', 'tquart1', 'tquart2', 'tquart3', 'tquart4', 'tquart5', 'tquart6'))
print(t)
# Out:
# Instance  min1 min2 min3 ...      tquart4      tquart5      tquart6
# -------- ----- ---- ---- ... ----------------- ------- ------------------
#        1 37.25  0.0  4.0 ...              1.12    36.0                1.3
#        2  38.0  0.0  2.0 ...             1.145    34.5                1.3
#        3  35.0  0.0  6.5 ...              0.83    36.5               0.94
#        4  33.0  0.0  8.5 ...               1.3   36.33                1.0
#        5  33.0  0.0  3.0 ...              1.12   31.25                0.5
#        6  37.0  0.0 5.75 ...              1.12    24.0               0.87
#        7 36.25  0.0  1.5 ...              0.94   23.75               0.83
#        8 12.75  0.0  0.0 ...              0.87    27.0               0.87
#        9   0.0  0.0  7.5 ...              0.94   20.75                1.3
#       10  21.0  0.0  0.0 ...              1.12    23.5                1.3
#      ...   ...  ...  ... ...               ...     ...                ...
# ...

# %% [markdown]
# ### c) iii)

# %% [markdown]
# #### 3 Features chosen - min, max and mean

# %% [markdown]
# ### d) i)

# %%
min1b1tr=[]
min2b1tr=[]
min6b1tr=[]

min1b1tr=min1b1[2:]
min2b1tr=min2b1[2:]
min6b1tr=min6b1[2:]

min1b2tr=[]
min2b2tr=[]
min6b2tr=[]

min1b2tr=min1b2[2:]
min2b2tr=min2b2[2:]
min6b2tr=min6b2[2:]

min1cyctr=[]
min2cyctr=[]
min6cyctr=[]

min1cyctr=min1cyc[3:]
min2cyctr=min2cyc[3:]
min6cyctr=min6cyc[3:]

min1lyingtr=[]
min2lyingtr=[]
min6lyingtr=[]

min1lyingtr=min1lying[3:]
min2lyingtr=min2lying[3:]
min6lyingtr=min6lying[3:]

min1sittr=[]
min2sittr=[]
min6sittr=[]

min1sittr=min1sit[3:]
min2sittr=min2sit[3:]
min6sittr=min6sit[3:]

min1standtr=[]
min2standtr=[]
min6standtr=[]

min1standtr=min1stand[3:]
min2standtr=min2stand[3:]
min6standtr=min6stand[3:]

min1walktr=[]
min2walktr=[]
min6walktr=[]

min1walktr=min1walk[3:]
min2walktr=min2walk[3:]
min6walktr=min6walk[3:]

min1tr=min1b1tr + min1b2tr + min1cyctr + min1lyingtr + min1sittr + min1standtr + min1walktr
min2tr=min2b1tr + min2b2tr + min2cyctr + min2lyingtr + min2sittr + min2standtr + min2walktr
min6tr=min6b1tr + min6b2tr + min6cyctr + min6lyingtr + min6sittr + min6standtr + min6walktr

# %%
max1b1tr=[]
max2b1tr=[]
max6b1tr=[]

max1b1tr=max1b1[2:]
max2b1tr=max2b1[2:]
max6b1tr=max6b1[2:]

max1b2tr=[]
max2b2tr=[]
max6b2tr=[]

max1b2tr=max1b2[2:]
max2b2tr=max2b2[2:]
max6b2tr=max6b2[2:]

max1cyctr=[]
max2cyctr=[]
max6cyctr=[]

max1cyctr=max1cyc[3:]
max2cyctr=max2cyc[3:]
max6cyctr=max6cyc[3:]

max1lyingtr=[]
max2lyingtr=[]
max6lyingtr=[]

max1lyingtr=max1lying[3:]
max2lyingtr=max2lying[3:]
max6lyingtr=max6lying[3:]

max1sittr=[]
max2sittr=[]
max6sittr=[]

max1sittr=max1sit[3:]
max2sittr=max2sit[3:]
max6sittr=max6sit[3:]

max1standtr=[]
max2standtr=[]
max6standtr=[]

max1standtr=max1stand[3:]
max2standtr=max2stand[3:]
max6standtr=max6stand[3:]

max1walktr=[]
max2walktr=[]
max6walktr=[]

max1walktr=max1walk[3:]
max2walktr=max2walk[3:]
max6walktr=max6walk[3:]

max1tr=max1b1tr + max1b2tr + max1cyctr + max1lyingtr + max1sittr + max1standtr + max1walktr
max2tr=max2b1tr + max2b2tr + max2cyctr + max2lyingtr + max2sittr + max2standtr + max2walktr
max6tr=max6b1tr + max6b2tr + max6cyctr + max6lyingtr + max6sittr + max6standtr + max6walktr

# %%
mean1b1tr=[]
mean2b1tr=[]
mean6b1tr=[]

mean1b1tr=mean1b1[2:]
mean2b1tr=mean2b1[2:]
mean6b1tr=mean6b1[2:]

mean1b2tr=[]
mean2b2tr=[]
mean6b2tr=[]

mean1b2tr=mean1b2[2:]
mean2b2tr=mean2b2[2:]
mean6b2tr=mean6b2[2:]

mean1cyctr=[]
mean2cyctr=[]
mean6cyctr=[]

mean1cyctr=mean1cyc[3:]
mean2cyctr=mean2cyc[3:]
mean6cyctr=mean6cyc[3:]

mean1lyingtr=[]
mean2lyingtr=[]
mean6lyingtr=[]

mean1lyingtr=mean1lying[3:]
mean2lyingtr=mean2lying[3:]
mean6lyingtr=mean6lying[3:]

mean1sittr=[]
mean2sittr=[]
mean6sittr=[]

mean1sittr=mean1sit[3:]
mean2sittr=mean2sit[3:]
mean6sittr=mean6sit[3:]

mean1standtr=[]
mean2standtr=[]
mean6standtr=[]

mean1standtr=mean1stand[3:]
mean2standtr=mean2stand[3:]
mean6standtr=mean6stand[3:]

mean1walktr=[]
mean2walktr=[]
mean6walktr=[]

mean1walktr=mean1walk[3:]
mean2walktr=mean2walk[3:]
mean6walktr=mean6walk[3:]

mean1tr=mean1b1tr + mean1b2tr + mean1cyctr + mean1lyingtr + mean1sittr + mean1standtr + mean1walktr
mean2tr=mean2b1tr + mean2b2tr + mean2cyctr + mean2lyingtr + mean2sittr + mean2standtr + mean2walktr
mean6tr=mean6b1tr + mean6b2tr + mean6cyctr + mean6lyingtr + mean6sittr + mean6standtr + mean6walktr

# %%
activity=[]
activity1=[]
activity2=[]
for i in range(1,10):
    a='Bending'
    activity1.append(a)
    
for i in range(1,61):
    a='Other'
    activity2.append(a)   
    
activity = activity1 + activity2

# %%
d={'min1tr': min1tr, 'min2tr': min2tr, 'min6tr': min6tr, 'max1tr': max1tr, 'max2tr': max2tr, 'max6tr': max6tr, 'mean1tr': mean1tr, 'mean2tr': mean2tr, 'mean6tr': mean6tr, 'Activity': activity}
dftable = pd.DataFrame(data=d)
print(dftable)
# Out:
#     min1tr  min2tr  min6tr  max1tr  max2tr  max6tr    mean1tr   mean2tr  \
# 0    35.00     0.0    0.00   47.40    1.70    1.79  43.954500  0.426250
# 1    33.00     0.0    0.00   47.75    3.00    2.18  42.179813  0.696042
# 2    33.00     0.0    0.00   45.75    2.83    1.79  41.678063  0.535979
# 3    37.00     0.0    0.00   48.00    1.58    5.26  43.454958  0.378083
# 4    36.25     0.0    0.00   48.00    1.50    2.96  43.969125  0.413125
# 5    21.00     0.0    0.00   50.00    9.90   13.61  32.586208  0.516125
# 6    27.50     0.0    0.00   33.00    1.00    6.40  29.881938  0.256438
# 7    19.00     0.0    0.00   45.50    6.40    6.73  30.938104  0.467167
# 8    25.00     0.0    0.00   47.50    6.38    4.92  31.058250  0.405458
# 9    19.00     0.0    0.00   44.00   12.28    9.98  36.228396  2.831687
# 10   26.50     0.0    0.00   44.33   12.89    8.19  36.687292  2.973042
# 11   25.33     0.0    0.00   45.00   10.84    9.50  37.114312  2.730000
# ...

# %%
import seaborn as sb
sb.pairplot(data=dftable,hue='Activity', vars=['min1tr', 'min2tr', 'min6tr', 'max1tr', 'max2tr', 'max6tr', 'mean1tr', 'mean2tr', 'mean6tr'])

# %% [markdown]
# ### d) ii)

# %%
abc=[]
min1train=[]
min2train=[]
min6train=[]
max1train=[]
max2train=[]
max6train=[]
mean1train=[]
mean2train=[]
mean6train=[]
folders=[0,bend1, bend2, cyc, lying, sit, stand, walk]
l=2
for m in range(1,len(folders)):
    if m==1 or m==2:
        s=3
    else:
        s=4    
    for i in range(s,len(folders[m])):
        abc=np.array_split(folders[m][i], l)
        for j in range(0,l):
            min1=np.min(abc[j].avg_rss12)
            min1train.append(min1)
            min2=np.min(abc[j].var_rss12)
            min2train.append(min2)
            min6=np.min(abc[j].var_rss23)
            min6train.append(min6)
            
            max1=np.max(abc[j].avg_rss12)
            max1train.append(max1)
            max2=np.max(abc[j].var_rss12)
            max2train.append(max2)
            max6=np.max(abc[j].var_rss23)
            max6train.append(max6)
            
            mean1=np.mean(abc[j].avg_rss12)
            mean1train.append(mean1)
            mean2=np.mean(abc[j].var_rss12)
            mean2train.append(mean2)
            mean6=np.mean(abc[j].var_rss23)
            mean6train.append(mean6)

# %%
activitytrain=[]
activitytrain1=[]
activitytrain2=[]
for i in range(1,(9*l)+1):
    a='Bending'
    activitytrain1.append(a)
    
for i in range(1,(60*l)+1):
    a='Other'
    activitytrain2.append(a)   
    
activitytrain = activitytrain1 + activitytrain2

# %%
d1={'min1tr': min1train, 'min2tr': min2train, 'min6tr': min6train, 'max1tr': max1train, 'max2tr': max2train, 'max6tr': max6train, 'mean1tr': mean1train, 'mean2tr': mean2train, 'mean6tr': mean6train, 'Activity': activitytrain}
dftable1 = pd.DataFrame(data=d1)
print(dftable1)
# Out:
#      min1tr  min2tr  min6tr  max1tr  max2tr  max6tr    mean1tr   mean2tr  \
# 0     36.50    0.00    0.00   46.50    1.50    1.79  44.057167  0.381042
# 1     35.00    0.00    0.00   47.40    1.70    1.50  43.851833  0.471458
# 2     33.75    0.00    0.00   47.75    3.00    1.53  43.278875  0.673292
# 3     33.00    0.00    0.00   46.00    2.86    2.18  41.080750  0.718792
# 4     33.00    0.00    0.00   45.75    2.83    1.79  41.621208  0.623083
# 5     39.25    0.00    0.00   43.67    1.12    1.50  41.734917  0.448875
# 6     39.00    0.00    0.00   48.00    1.30    5.26  44.117042  0.250042
# 7     37.00    0.00    0.00   46.50    1.58    4.06  42.792875  0.506125
# 8     36.67    0.00    0.00   45.00    1.30    2.28  43.486208  0.378667
# 9     36.25    0.00    0.00   48.00    1.50    2.96  44.452042  0.447583
# 10    21.00    0.00    0.00   50.00    9.90   13.61  32.014375  0.587875
# 11    27.00    0.00    0.00   36.00    1.87    6.02  33.158042  0.444375
# ...

# %%
sb.pairplot(data=dftable1,hue='Activity', vars=['min1tr', 'min2tr', 'min6tr', 'max1tr', 'max2tr', 'max6tr', 'mean1tr', 'mean2tr', 'mean6tr'])

# %% [markdown]
# #### Minute differences seen between the two scatterplot matrices

# %% [markdown]
# ### d) iii)

# %%
def main(l):
    abc=[]
    min1train=[]
    min2train=[]
    min3train=[]
    min4train=[]
    min5train=[]
    min6train=[]
    max1train=[]
    max2train=[]
    max3train=[]
    max4train=[]
    max5train=[]
    max6train=[]
    mean1train=[]
    mean2train=[]
    mean3train=[]
    mean4train=[]
    mean5train=[]
    mean6train=[]
    median1train=[]
    median2train=[]
    median3train=[]
    median4train=[]
    median5train=[]
    median6train=[]
    std1train=[]
    std2train=[]
    std3train=[]
    std4train=[]
    std5train=[]
    std6train=[]
    fquart1train=[]
    fquart2train=[]
    fquart3train=[]
    fquart4train=[]
    fquart5train=[]
    fquart6train=[]
    tquart1train=[]
    tquart2train=[]
    tquart3train=[]
    tquart4train=[]
    tquart5train=[]
    tquart6train=[]    


    def get_min(j):
        min1=np.min(abc[j].avg_rss12)
        min1train.append(min1)
        min2=np.min(abc[j].var_rss12)
        min2train.append(min2)
        min3=np.min(abc[j].avg_rss13)
        min3train.append(min3)
        min4=np.min(abc[j].var_rss13)
        min4train.append(min4)
        min5=np.min(abc[j].avg_rss23)
        min5train.append(min5)
        min6=np.min(abc[j].var_rss23)
        min6train.append(min6)
        return;

    def get_max(j):
        max1=np.max(abc[j].avg_rss12)
        max1train.append(max1)
        max2=np.max(abc[j].var_rss12)
        max2train.append(max2)
        max3=np.max(abc[j].avg_rss13)
        max3train.append(max3)
        max4=np.max(abc[j].var_rss13)
        max4train.append(max4)
        max5=np.max(abc[j].avg_rss23)
        max5train.append(max5)
        max6=np.max(abc[j].var_rss23)
        max6train.append(max6)
        return;


    def get_mean(j):
        mean1=np.mean(abc[j].avg_rss12)
        mean1train.append(mean1)
        mean2=np.mean(abc[j].var_rss12)
        mean2train.append(mean2)
        mean3=np.mean(abc[j].avg_rss13)
        mean3train.append(mean3)
        mean4=np.mean(abc[j].var_rss13)
        mean4train.append(mean4)
        mean5=np.mean(abc[j].avg_rss23)
        mean5train.append(mean5)
        mean6=np.mean(abc[j].var_rss23)
        mean6train.append(mean6)
        return;


    def get_median(j):
        median1=np.median(abc[j].avg_rss12)
        median1train.append(median1)
        median2=np.median(abc[j].var_rss12)
        median2train.append(median2)
        median3=np.median(abc[j].avg_rss13)
        median3train.append(median3)
        median4=np.median(abc[j].var_rss13)
        median4train.append(median4)
        median5=np.median(abc[j].avg_rss23)
        median5train.append(median5)
        median6=np.median(abc[j].var_rss23)
        median6train.append(median6)
        return;


    def get_std(j):
        std1=np.std(abc[j].avg_rss12)
        std1train.append(std1)
        std2=np.std(abc[j].var_rss12)
        std2train.append(std2)
        std3=np.std(abc[j].avg_rss13)
        std3train.append(std3)
        std4=np.std(abc[j].var_rss13)
        std4train.append(std4)
        std5=np.std(abc[j].avg_rss23)
        std5train.append(std5)
        std6=np.std(abc[j].var_rss23)
        std6train.append(std6)
        return;


    def get_fquart(j):
        fquart1=np.percentile(abc[j].avg_rss12,25)
        fquart1train.append(fquart1)
        fquart2=np.percentile(abc[j].var_rss12,25)
        fquart2train.append(fquart2)
        fquart3=np.percentile(abc[j].avg_rss13,25)
        fquart3train.append(fquart3)
        fquart4=np.percentile(abc[j].var_rss13,25)
        fquart4train.append(fquart4)
        fquart5=np.percentile(abc[j].avg_rss23,25)
        fquart5train.append(fquart5)
        fquart6=np.percentile(abc[j].var_rss23,25)
        fquart6train.append(fquart6)
        return;


    def get_tquart(j):
        tquart1=np.percentile(abc[j].avg_rss12,75)
        tquart1train.append(tquart1)
        tquart2=np.percentile(abc[j].var_rss12,75)
        tquart2train.append(tquart2)
        tquart3=np.percentile(abc[j].avg_rss13,75)
        tquart3train.append(tquart3)
        tquart4=np.percentile(abc[j].var_rss13,75)
        tquart4train.append(tquart4)
        tquart5=np.percentile(abc[j].avg_rss23,75)
        tquart5train.append(tquart5)
        tquart6=np.percentile(abc[j].var_rss23,75)
        tquart6train.append(tquart6)
        return;




    folders=[0,bend1, bend2, cyc, lying, sit, stand, walk]
    
    for m in range(1,len(folders)):
        if m==1 or m==2:
            s=3
        else:
            s=4    
        for i in range(s,len(folders[m])):
            abc=np.array_split(folders[m][i], l)
            for j in range(0,l):
                get_min(j)
                get_max(j)
                get_mean(j)
                get_median(j)
                get_std(j)
                get_fquart(j)
                get_tquart(j)

    activitytrain=[]
    activitytrain1=[]
    activitytrain2=[]
    for i in range(1,(9*l)+1):
        a='Bending'
        activitytrain1.append(a)

    for i in range(1,(60*l)+1):
        a='Other'
        activitytrain2.append(a)   

    activitytrain = activitytrain1 + activitytrain2



    d3={'min1tr': min1train, 'min2tr': min2train,'min3tr': min3train, 'min4tr': min4train, 'min5tr': min5train, 'min6tr': min6train, 'max1tr': max1train, 'max2tr': max2train,'max3tr': max3train, 'max4tr': max4train, 'max5tr': max5train, 'max6tr': max6train, 'mean1tr': mean1train, 'mean2tr': mean2train,'mean3tr': mean3train, 'mean4tr': mean4train, 'mean5tr': mean5train, 'mean6tr': mean6train, 'median1tr': median1train, 'median2tr': median2train,'median3tr': median3train, 'median4tr': median4train, 'median5tr': median5train, 'median6tr': median6train, 'std1tr': std1train, 'std2tr': std2train,'std3tr': std3train, 'std4tr': std4train, 'std5tr': std5train, 'std6tr': std6train, 'fquart1tr': fquart1train, 'fquart2tr': fquart2train,'fquart3tr': fquart3train, 'fquart4tr': fquart4train, 'fquart5tr': fquart5train, 'fquart6tr': fquart6train, 'tquart1tr': tquart1train, 'tquart2tr': tquart2train,'tquart3tr': tquart3train, 'tquart4tr': tquart4train, 'tquart5tr': tquart5train, 'tquart6tr': tquart6train, 'Activity': activitytrain}
    dftable3 = pd.DataFrame(data=d3)
    #print(dftable3)
    return;

# %%
from sklearn import datasets
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score

CVscore_best = 0
score_best = 0
Lvalue_best = 0
for l in range(1,21):
    main(l)
    Y_Train = dftable3['Activity']
    X_Train = dftable3.drop(['Activity'], axis=1)
    Log_Reg = LogisticRegression()
    
    for i in range(1,len(X_Train.columns)):
        RFE_res = RFE(estimator=Log_Reg, n_features_to_select= i)
        RFE_res.fit(X_Train, Y_Train)
        CV_score = cross_val_score(RFE_res, X_Train, Y_Train, cv=5, scoring='accuracy')  
        Mean_score  =  np.mean(CV_score)
        if Mean_score > CVscore_best:
            CVscore_best = Mean_score
            n_features = i   
            Lvalue_best = l
            #features = feature_cols[RFE_res.support_]

print("The best value of L is : %d" %Lvalue_best )            
print("Optimal CV score is:" , CVscore_best)
print("Optimal number of features : %d" % n_features)
#print("The features are:", features)
# Out:
# The best value of L is : 1
# Optimal CV score is: 0.9238311688311688
# Optimal number of features : 30

# %% [markdown]
# ### d) iv)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
Y_Train = dftable3['Activity']
X_Train = dftable3.drop(['Activity'], axis=1)
Log_Reg = LogisticRegression()
Log_Reg.fit(X_Train, Y_Train)
Y_Predict=Log_Reg.predict(X_Train)
confusion_matrix(Y_Train,Y_Predict)
# Out:
# array([[ 31,   5],
#        [  3, 237]])

# %% [markdown]
# ### d) v)

# %%
abc1=[]
min1test=[]
min2test=[]
min6test=[]
max1test=[]
max2test=[]
max6test=[]
mean1test=[]
mean2test=[]
mean6test=[]
folders=[0,bend1, bend2, cyc, lying, sit, stand, walk]
l=2
for m in range(1,len(folders)):
    if m==1 or m==2:
        s=3
    else:
        s=4    
    for i in range(1,s):
        abc1=np.array_split(folders[m][i], l)
        for j in range(0,l):
            min1=np.min(abc1[j].avg_rss12)
            min1test.append(min1)
            min2=np.min(abc1[j].var_rss12)
            min2test.append(min2)
            min6=np.min(abc1[j].var_rss23)
            min6test.append(min6)
            
            max1=np.max(abc1[j].avg_rss12)
            max1test.append(max1)
            max2=np.max(abc1[j].var_rss12)
            max2test.append(max2)
            max6=np.max(abc1[j].var_rss23)
            max6test.append(max6)
            
            mean1=np.mean(abc1[j].avg_rss12)
            mean1test.append(mean1)
            mean2=np.mean(abc1[j].var_rss12)
            mean2test.append(mean2)
            mean6=np.mean(abc1[j].var_rss23)
            mean6test.append(mean6)

# %%
activitytest=[]
activitytest1=[]
activitytest2=[]
for i in range(1,(4*l)+1):
    a='Bending'
    activitytest1.append(a)
    
for i in range(1,(15*l)+1):
    a='Other'
    activitytest2.append(a)   
    
activitytest = activitytest1 + activitytest2

# %%
d2={'min1tr': min1test, 'min2tr': min2test, 'min6tr': min6test, 'max1tr': max1test, 'max2tr': max2test, 'max6tr': max6test, 'mean1tr': mean1test, 'mean2tr': mean2test, 'mean6tr': mean6test, 'Activity': activitytest}
dftable2 = pd.DataFrame(data=d2)
print(dftable2)
# Out:
#     min1tr  min2tr  min6tr  max1tr  max2tr  max6tr    mean1tr   mean2tr  \
# 0    38.00    0.00     0.0   42.33    1.22    1.50  40.946958  0.375667
# 1    37.25    0.00     0.0   45.00    1.30    1.92  40.302625  0.341542
# 2    41.75    0.00     0.0   44.25    0.94    1.50  42.643292  0.355000
# 3    38.00    0.00     0.0   45.67    1.22    3.11  42.982333  0.389875
# 4    12.75    0.00     0.0   51.00    6.87    2.64  24.675375  0.774500
# 5    17.50    0.00     0.0   27.50    2.77    4.97  24.450542  0.407167
# 6    26.50    0.00     0.0   31.33    1.25    4.03  29.071583  0.231208
# 7     0.00    0.00     0.0   42.75    7.76    6.76  25.857625  0.668208
# 8    24.25    0.00     0.0   45.00    8.18    9.07  36.954208  2.392667
# 9    29.00    0.00     0.0   44.67    8.58    9.34  37.399875  2.355750
# 10   29.25    0.00     0.0   44.75    8.95    8.57  37.592250  2.111625
# 11   28.75    0.00     0.0   44.00    9.91    9.62  37.530125  2.049750
# ...

# %%
def main(l):
    abc=[]
    min1test=[]
    min2test=[]
    min3test=[]
    min4test=[]
    min5test=[]
    min6test=[]
    max1test=[]
    max2test=[]
    max3test=[]
    max4test=[]
    max5test=[]
    max6test=[]
    mean1test=[]
    mean2test=[]
    mean3test=[]
    mean4test=[]
    mean5test=[]
    mean6test=[]
    median1test=[]
    median2test=[]
    median3test=[]
    median4test=[]
    median5test=[]
    median6test=[]
    std1test=[]
    std2test=[]
    std3test=[]
    std4test=[]
    std5test=[]
    std6test=[]
    fquart1test=[]
    fquart2test=[]
    fquart3test=[]
    fquart4test=[]
    fquart5test=[]
    fquart6test=[]
    tquart1test=[]
    tquart2test=[]
    tquart3test=[]
    tquart4test=[]
    tquart5test=[]
    tquart6test=[]    


    def get_min(j):
        min1=np.min(abc[j].avg_rss12)
        min1test.append(min1)
        min2=np.min(abc[j].var_rss12)
        min2test.append(min2)
        min3=np.min(abc[j].avg_rss13)
        min3test.append(min3)
        min4=np.min(abc[j].var_rss13)
        min4test.append(min4)
        min5=np.min(abc[j].avg_rss23)
        min5test.append(min5)
        min6=np.min(abc[j].var_rss23)
        min6test.append(min6)
        return;

    def get_max(j):
        max1=np.max(abc[j].avg_rss12)
        max1test.append(max1)
        max2=np.max(abc[j].var_rss12)
        max2test.append(max2)
        max3=np.max(abc[j].avg_rss13)
        max3test.append(max3)
        max4=np.max(abc[j].var_rss13)
        max4test.append(max4)
        max5=np.max(abc[j].avg_rss23)
        max5test.append(max5)
        max6=np.max(abc[j].var_rss23)
        max6test.append(max6)
        return;


    def get_mean(j):
        mean1=np.mean(abc[j].avg_rss12)
        mean1test.append(mean1)
        mean2=np.mean(abc[j].var_rss12)
        mean2test.append(mean2)
        mean3=np.mean(abc[j].avg_rss13)
        mean3test.append(mean3)
        mean4=np.mean(abc[j].var_rss13)
        mean4test.append(mean4)
        mean5=np.mean(abc[j].avg_rss23)
        mean5test.append(mean5)
        mean6=np.mean(abc[j].var_rss23)
        mean6test.append(mean6)
        return;


    def get_median(j):
        median1=np.median(abc[j].avg_rss12)
        median1test.append(median1)
        median2=np.median(abc[j].var_rss12)
        median2test.append(median2)
        median3=np.median(abc[j].avg_rss13)
        median3test.append(median3)
        median4=np.median(abc[j].var_rss13)
        median4test.append(median4)
        median5=np.median(abc[j].avg_rss23)
        median5test.append(median5)
        median6=np.median(abc[j].var_rss23)
        median6test.append(median6)
        return;


    def get_std(j):
        std1=np.std(abc[j].avg_rss12)
        std1test.append(std1)
        std2=np.std(abc[j].var_rss12)
        std2test.append(std2)
        std3=np.std(abc[j].avg_rss13)
        std3test.append(std3)
        std4=np.std(abc[j].var_rss13)
        std4test.append(std4)
        std5=np.std(abc[j].avg_rss23)
        std5test.append(std5)
        std6=np.std(abc[j].var_rss23)
        std6test.append(std6)
        return;


    def get_fquart(j):
        fquart1=np.percentile(abc[j].avg_rss12,25)
        fquart1test.append(fquart1)
        fquart2=np.percentile(abc[j].var_rss12,25)
        fquart2test.append(fquart2)
        fquart3=np.percentile(abc[j].avg_rss13,25)
        fquart3test.append(fquart3)
        fquart4=np.percentile(abc[j].var_rss13,25)
        fquart4test.append(fquart4)
        fquart5=np.percentile(abc[j].avg_rss23,25)
        fquart5test.append(fquart5)
        fquart6=np.percentile(abc[j].var_rss23,25)
        fquart6test.append(fquart6)
        return;


    def get_tquart(j):
        tquart1=np.percentile(abc[j].avg_rss12,75)
        tquart1test.append(tquart1)
        tquart2=np.percentile(abc[j].var_rss12,75)
        tquart2test.append(tquart2)
        tquart3=np.percentile(abc[j].avg_rss13,75)
        tquart3test.append(tquart3)
        tquart4=np.percentile(abc[j].var_rss13,75)
        tquart4test.append(tquart4)
        tquart5=np.percentile(abc[j].avg_rss23,75)
        tquart5test.append(tquart5)
        tquart6=np.percentile(abc[j].var_rss23,75)
        tquart6test.append(tquart6)
        return;




    folders=[0,bend1, bend2, cyc, lying, sit, stand, walk]
    
    for m in range(1,len(folders)):
        if m==1 or m==2:
            s=3
        else:
            s=4    
        for i in range(1,s):
            abc=np.array_split(folders[m][i], l)
            for j in range(0,l):
                get_min(j)
                get_max(j)
                get_mean(j)
                get_median(j)
                get_std(j)
                get_fquart(j)
                get_tquart(j)

    activitytest=[]
    activitytest1=[]
    activitytest2=[]
    for i in range(1,(4*l)+1):
        a='Bending'
        activitytest1.append(a)

    for i in range(1,(15*l)+1):
        a='Other'
        activitytest2.append(a)   

    activitytest = activitytest1 + activitytest2
    d4={'min1tr': min1test, 'min2tr': min2test,'min3tr': min3test, 'min4tr': min4test, 'min5tr': min5test, 'min6tr': min6test, 'max1tr': max1test, 'max2tr': max2test,'max3tr': max3test, 'max4tr': max4test, 'max5tr': max5test, 'max6tr': max6test, 'mean1tr': mean1test, 'mean2tr': mean2test,'mean3tr': mean3test, 'mean4tr': mean4test, 'mean5tr': mean5test, 'mean6tr': mean6test, 'median1tr': median1test, 'median2tr': median2test,'median3tr': median3test, 'median4tr': median4test, 'median5tr': median5test, 'median6tr': median6test, 'std1tr': std1test, 'std2tr': std2test,'std3tr': std3test, 'std4tr': std4test, 'std5tr': std5test, 'std6tr': std6test, 'fquart1tr': fquart1test, 'fquart2tr': fquart2test,'fquart3tr': fquart3test, 'fquart4tr': fquart4test, 'fquart5tr': fquart5test, 'fquart6tr': fquart6test, 'tquart1tr': tquart1test, 'tquart2tr': tquart2test,'tquart3tr': tquart3test, 'tquart4tr': tquart4test, 'tquart5tr': tquart5test, 'tquart6tr': tquart6test, 'Activity': activitytest}
    dftable4 = pd.DataFrame(data=d4)
    #print(dftable4)
    return;

# %% [markdown]
# ### d) vi)

# %% [markdown]
# #### From confusion matrix, we can say it is well seperated, instability present.
